# %%
import pandas as pd
rfile = '/Users/emilysu/Desktop/PathFX/PathFX/results/pathfx_demo/DB00983/DB00983_merged_neighborhood__assoc_table_.txt'
df_Formoterol_DB00983 = pd.read_csv(rfile,sep='\t')
df_Formoterol_DB00983
# Out:
#     rank                             phenotype       cui  assoc in neigh  \
# 0    256                           Tachycardia  C0039231               8
# 1    257                 Neuroendocrine Tumors  C0206754              16
# 2    258                   Hyperparathyroidism  C0020502               7
# 3    260               Adrenal Gland Neoplasms  C0001624               9
# 4    261                          Osteomalacia  C0029442               6
# 5    263                  Hypertensive disease  C0020538              38
# 6    265          Hyperparathyroidism, Primary  C0221002               7
# 7    266                    Pituitary Diseases  C0032002              14
# 8    267                         Hypercalcemia  C0020437               9
# 9    268                      Pheochromocytoma  C0031511              15
# 10   274                     Alzheimer disease  C0002395              48
# 11   275        Medullary carcinoma of thyroid  C0238462              13
# ...

# %%
for i in df_Formoterol_DB00983["phenotype"]:
    if "breast" in i.lower():
        print(i)
# Out:
# Atypical Ductal Breast Hyperplasia

# %%
df_Formoterol_DB00983.to_csv("Formoterol_DB00983.csv")
