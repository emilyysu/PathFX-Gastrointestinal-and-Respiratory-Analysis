# %%
import pandas as pd
rfile = '/Users/emilysu/Desktop/PathFX/PathFX/results/pathfx_demo/DB00927/DB00927_merged_neighborhood__assoc_table_.txt'
df_Famotidine_DB00927 = pd.read_csv(rfile,sep='\t')
df_Famotidine_DB00927
# Out:
#      rank                      phenotype       cui  assoc in neigh  \
# 0       2           Hypertensive disease  C0020538              22
# 1      92        Adrenal Gland Neoplasms  C0001624               8
# 2      94                    Tachycardia  C0039231               7
# 3      95             Pituitary Diseases  C0032002              11
# 4      97               Pheochromocytoma  C0031511              13
# ..    ...                            ...       ...             ...
# 250   805      Cholestasis, Extrahepatic  C0005398               2
# 251   806     Major affective disorder 7  C2700438               2
# 252   807                Plaque, Amyloid  C2936349               4
# 253   808                  Endometriosis  C0014175               7
# 254   809  Hereditary Malignant Neoplasm  C1333600               2
#
#      assoc in intom   probability  Benjamini-Hochberg  \
# 0              1309  0.000000e+00        9.115770e-07
# ...

# %%
for i in df_Famotidine_DB00927["phenotype"]:
    if "breast" in i.lower():
        print(i)
# Out:
# Atypical Ductal Breast Hyperplasia

# %%
df_Famotidine_DB00927.to_csv("Famotidine_DB00927.csv")
