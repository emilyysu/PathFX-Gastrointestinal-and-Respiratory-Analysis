# %%
import pandas as pd
rfile = '/Users/emilysu/Desktop/PathFX/PathFX/results/pathfx_demo/DB01222/DB01222_merged_neighborhood__assoc_table_.txt'
df_Budesonide_DB01222 = pd.read_csv(rfile,sep='\t')
df_Budesonide_DB01222
# Out:
#      rank                   phenotype       cui  assoc in neigh  \
# 0     318           Anxiety Disorders  C0003469              33
# 1     319        Hypertensive disease  C0020538              76
# 2     320                   Pneumonia  C0032285              34
# 3     321           Mental Depression  C0011570              39
# 4     322             Lobar Pneumonia  C0032300              16
# ..    ...                         ...       ...             ...
# 360   849    Stevens-Johnson Syndrome  C0038325               6
# 361   850      IGA Glomerulonephritis  C0017661              13
# 362   851  Acute Kidney Insufficiency  C1565662               7
# 363   852              Panic Disorder  C0030319               8
# 364   853      Pulmonary Eosinophilia  C0034068               4
#
#      assoc in intom   probability  Benjamini-Hochberg  \
# 0               439  5.067535e-11            0.000057
# 1              1309  5.363654e-11            0.000058
# ...

# %%
for i in df_Budesonide_DB01222["phenotype"]:
    if "breast" in i.lower():
        print(i)
# Out:
# Neoplasm of the breast

# %%
df_Budesonide_DB01222.to_csv("Budesonide_DB01222.csv")
