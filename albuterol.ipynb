# %%
import pandas as pd
rfile = '/Users/emilysu/Desktop/PathFX/PathFX/results/pathfx_demo/DB01001/DB01001_merged_neighborhood__assoc_table_.txt'
df_Albuterol_DB01001 = pd.read_csv(rfile,sep='\t')
df_Albuterol_DB01001
# Out:
#      rank                phenotype       cui  assoc in neigh  assoc in intom  \
# 0     207        Alzheimer disease  C0002395              46            1982
# 1     208     Hypertensive disease  C0020538              35            1309
# 2     209    Neuroendocrine Tumors  C0206754              16             259
# 3     212              Tachycardia  C0039231               8              52
# 4     215       Pituitary Diseases  C0032002              14             239
# ..    ...                      ...       ...             ...             ...
# 164   641      Multinodular goiter  C0342208               3              34
# 165   642     Sparse axillary hair  C1858574               3              34
# 166   643        Diabetes Mellitus  C0011849              28            1791
# 167   644                Eclampsia  C0013537               7             193
# 168   645  Somatotropin deficiency  C0271561               3              35
#
#       probability  Benjamini-Hochberg  \
# ...

# %%
for i in df_Albuterol_DB01001["phenotype"]:
    if "breast" in i.lower():
        print(i)
# Out:
# Atypical Ductal Breast Hyperplasia
# Neoplasm of the breast

# %%
df_Albuterol_DB01001.to_csv("Albuterol_DB01001.csv")
